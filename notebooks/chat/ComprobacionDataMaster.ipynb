# %%
import pandas as pd

df = pd.read_csv("../../src/chat/aupa_master_v7.csv")
print(df[df["nombre"].str.contains("GANBARA", case=False, na=False)][["nombre", "categoria", "municipio"]])
# Out:
#        nombre    categoria                 municipio
# 2     GANBARA  Alojamiento                    Bilbao
# 247   GANBARA  Alojamiento         Valdegovía/Gaubea
# 3872  Ganbara    Culinario  Donostia / San Sebastián

# %%
import pandas as pd
df = pd.read_csv("../../src/chat/aupa_master_v7.csv")
rutas = df[df["categoria"] == "Naturaleza"]
print(rutas["municipio"].value_counts().head(20))
# Out:
# municipio
# Donostia / San Sebastián    12
# Vitoria-Gasteiz              9
# Arratzua-Ubarrundia          7
# Valdegovía/Gaubea            5
# Mutriku                      5
# Bilbao                       5
# Getxo                        4
# Hondarribia                  4
# Deba                         4
# Laguardia                    4
# Ibarrangelu                  3
# Getaria                      3
# Gautegiz Arteaga             3
# Mundaka                      3
# Barrika                      3
# Zumaia                       3
# Irun                         3
# Arraia-Maeztu                3
# Bermeo                       2
# Lekeitio                     2
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("../../src/chat/aupa_master_v7.csv")
cols = ["nombre", "categoria", "subcategoria", "descripcion", "municipio", "territorio"]
print(df[df["nombre"].isin(["Berriatua", "Otxandio"])][cols].to_string())
# Out:
#         nombre  categoria         subcategoria                                                                             descripcion  municipio territorio
# 788  Berriatua  Servicios  Destinos turísticos  Berriatua está situado en el territorio histórico de Bizkaia, dentro de la comarca ...  Berriatua    BIZKAIA
# 928   Otxandio  Servicios  Destinos turísticos         Rodeada de montañas y fronteriza con el territorio histórico de Álava, Otxan...   Otxandio    BIZKAIA
